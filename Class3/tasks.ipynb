# %%
class Enviornment:
        def __init__(self):
            self.componentboard = [ 'V', 'S', 'V',
                                    'S', 'S', 'V',
                                    'V', 'S', 'S'
                                 ]
        def get_percept(self, position):
                 return self.componentboard[position]
            
        def fix_vunerability(self, position):
                self.componentboard[position] = 'S'
        
        def display_grid(self, position):
                grid_with_agent = self.componentboard[:]
                grid_with_agent[position] = 'A'
                for i in range(0, 9, 3):
                    print(f"{grid_with_agent[i:i+3]}")
                print()

class cybersecurity:
        def __init(self, envmodel):
            self.envmodel = envmodel
        
        def SystemScan(self):
            positions = []
            for i in range(9):
                if(self.envmodel[i] == 'V'):
                    positions.append(i)
            return positions

        def PatchingVunrabilities(self, vunerabilities):
            for i in range(len(vunerabilities)):
                index = vunerabilities[i]
                self.envmodel[index] = 'S'
                print(f"vunerability at {index}, was fixed")

        def FinalSystemCheck(self):
            check = False
            for i in range(9):
                positions = [] 

                if(self.envmodel[i] == 'V'):
                    positions.append(i)
                    check = True
                    print(f"Vunerability present at {i}")
            if check :
                return 1
            else :
                return 0 

def run_Agent(agent, enviornment, steps):
        for step in range(steps):
            percept = enviornment.get_percept(agent.positions)
# Out:
#   Cell In[1], line 44
#
#     ^
# IndentationError: expected an indented block
