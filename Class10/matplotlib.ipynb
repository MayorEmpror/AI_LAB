# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots()             # Create a figure containing a single Axes.
ax.plot([1, 2, 3, 4, 5, 6, 7], [1, 4, 2, 3, 1, 4, 6])  # Plot some data on the Axes.
plt.show()

# %%
b = np.matrix([[1, 2], [3, 4]])
b_asarray = np.asarray(b)
print(b_asarray)
# Out:
# [[1 2]
#  [3 4]]
